# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

main_experiments_path = "../experiments"
housing_experiment_path = "../../15_incremental_rbf_housing/experiments"

main_experiments = []


method_names = [
    "svr",
    "pls",
    "gradboost",
    "mlp_0.01",
    "mlp_0.001",
    "mlp_0.0001",
    "rbf_full_0.01",
    "rbf_full_0.001",
    "rbf_full_0.0001",
    "rbf_diag_0.01",
    "rbf_diag_0.001",
    "rbf_diag_0.0001",
    "rbf_scal_0.01",
    "rbf_scal_0.001",
    "rbf_scal_0.0001",
    "rbf_univ_0.01",
    "rbf_univ_0.001",
    "rbf_univ_0.0001",
    "ffn_0.1_0.01",
    "ffn_0.1_0.001",
    "ffn_0.1_0.0001",
    "ffn_1_0.01",
    "ffn_1_0.001",
    "ffn_1_0.0001",
    "ffn_10_0.01",
    "ffn_10_0.001",
    "ffn_10_0.0001",
    "uffn_0.1_0.01",
    "uffn_0.1_0.001",
    "uffn_0.1_0.0001",
    "uffn_1_0.01",
    "uffn_1_0.001",
    "uffn_1_0.0001",
    "uffn_10_0.01",
    "uffn_10_0.001",
    "uffn_10_0.0001",
]


condensed_method_names = [
    "svr",
    "pls",
    "gradboost",
    "mlp",
    "rbf_full",
    "rbf_diag",
    "rbf_scal",
    "rbf_univ",
    "ffn",
    "uffn",
]



experiments_df = pd.DataFrame()


method_settings = os.listdir(main_experiments_path)

# sort by name

method_settings = sorted(method_settings)

#print all folders in the main experiments path
for method_setting in method_settings:
    #print(method_setting)
    # iterate over repetitions

    experiment_df = pd.DataFrame()

    for repetition in os.listdir(main_experiments_path + "/" + method_setting):
        #print(repetition)
        # iterate over files

        ## add this repetition to the experiment df as column
        experiment_df[repetition] = None

        dataset_folders = os.listdir(main_experiments_path + "/" + method_setting + "/" + repetition)

        ## sort the dataset folders by name
        dataset_folders = sorted(dataset_folders)

        for dataset in dataset_folders:
            
            if "data" in dataset and dataset != "data":
                #print(dataset)

                ## add this dataset to the experiment df as row if it is not already there
                if dataset not in experiment_df.index:
                    experiment_df.loc[dataset] = None

                try:
                    ## read the npy file
                    train_loss = np.load(main_experiments_path + "/" + method_setting + "/" + repetition + "/" + dataset+ "/" + "train_loss.npy")
                    val_loss = np.load(main_experiments_path + "/" + method_setting + "/" + repetition + "/" + dataset + "/" + "val_loss.npy")
                    test_loss = np.load(main_experiments_path + "/" + method_setting + "/" + repetition + "/" + dataset + "/" + "test_loss.npy")
                except Exception as e:
                    print("Error reading files for dataset: ", dataset, e)
                    continue
                
                if "rabe" in dataset:
                    ### plot the val loss
                    plt.title(dataset + " " + method_setting + " " + repetition)
                    plt.plot(val_loss)
                    plt.ylim(0, 100)
                    plt.show()
                
                ### extract the min val loss and pick the corresponding test loss

                min_val_loss = np.min(val_loss)
                min_val_loss_index = np.argmin(val_loss)

                min_test_loss = test_loss[min_val_loss_index]

                

                ## add the test loss to the experiment df
                experiment_df.loc[dataset, repetition] = min_test_loss

    ## order by dataset name
    experiment_df = experiment_df.sort_index()

    ## add a column which represents the mean of all repetitions
    experiment_df["mean"] = experiment_df.mean(axis=1)

    ## set mean to nan if there are any nans in the row
    experiment_df.loc[experiment_df.isnull().any(axis=1), "mean"] = np.nan

    ## add the experiment df to the experiments df
    experiments_df[method_setting] = experiment_df["mean"]


housing_experiments_df = pd.DataFrame()

method_settings = os.listdir(housing_experiment_path)

# sort by name
method_settings = sorted(method_settings)

#print all folders in the main experiments path
for method_setting in method_settings:
    #print(method_setting)
    # iterate over repetitions

    experiment_df = pd.DataFrame()

    for repetition in os.listdir(housing_experiment_path + "/" + method_setting):
        #print(repetition)
        # iterate over files

        ## add this repetition to the experiment df as column
        experiment_df[repetition] = None

        dataset_folders = os.listdir(housing_experiment_path + "/" + method_setting + "/" + repetition)

        ## sort the dataset folders by name
        dataset_folders = sorted(dataset_folders)

        dataset = "data"
        dataset_name = "housing"

        ## add this dataset to the experiment df as row if it is not already there
        if dataset_name not in experiment_df.index:
            experiment_df.loc[dataset_name] = None

        try:
            ## read the npy file
            train_loss = np.load(housing_experiment_path + "/" + method_setting + "/" + repetition + "/" + dataset+ "/" + "train_loss.npy")
            val_loss = np.load(housing_experiment_path + "/" + method_setting + "/" + repetition + "/" + dataset + "/" + "val_loss.npy")
            test_loss = np.load(housing_experiment_path + "/" + method_setting + "/" + repetition + "/" + dataset + "/" + "test_loss.npy")
        except Exception as e:
            print("Error reading files for dataset: ", dataset_name, e)
            continue

        ### extract the min val loss and pick the corresponding test loss
        min_val_loss = np.min(val_loss)
        min_val_loss_index = np.argmin(val_loss)

        min_test_loss = test_loss[min_val_loss_index]

        print("Min Val Loss: ", min_val_loss)
        #print("Corresponding Test Loss: ", min_test_loss)


        ## add the test loss to the experiment df
        experiment_df.loc[dataset_name, repetition] = min_test_loss

    ## order by dataset name
    experiment_df = experiment_df.sort_index()

    ## add a column which represents the mean of all repetitions
    experiment_df["mean"] = experiment_df.mean(axis=1)

    print(experiment_df)

    ## set mean to nan if there are any nans in the row
    experiment_df.loc[experiment_df.isnull().any(axis=1), "mean"] = np.nan

    #print(experiment_df)

    ## add the experiment df to the experiments df as a new row
    housing_experiments_df[method_setting] = experiment_df["mean"]


## add the housing experiments to the main experiments


#experiments_df = pd.concat([experiments_df, housing_experiments_df])


for i in range(36):
    ## rename column experiment_000001 to method_names[0]
    exp_name = "experiment_" + str(i+1).zfill(6)
    experiments_df = experiments_df.rename(columns={exp_name: method_names[i]})

experiments_df
# Out:
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000007/repetition_000003/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000007/repetition_000002/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000007/repetition_000000/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000007/repetition_000001/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000008/repetition_000003/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000008/repetition_000002/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000008/repetition_000000/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000008/repetition_000001/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000009/repetition_000003/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000009/repetition_000002/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000009/repetition_000000/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000009/repetition_000001/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000010/repetition_000003/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000010/repetition_000002/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data519_vinnie [Errno 2] No such file or directory: '../experiments/experiment_000010/repetition_000000/data519_vinnie/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000010/repetition_000001/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000011/repetition_000003/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000011/repetition_000002/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data663_rabe_266 [Errno 2] No such file or directory: '../experiments/experiment_000011/repetition_000000/data663_rabe_266/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000011/repetition_000001/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000012/repetition_000002/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000013/repetition_000003/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000013/repetition_000002/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000013/repetition_000000/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000013/repetition_000001/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000014/repetition_000003/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000014/repetition_000002/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000014/repetition_000000/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data529_pollen [Errno 2] No such file or directory: '../experiments/experiment_000014/repetition_000001/data529_pollen/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000015/repetition_000002/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000016/repetition_000003/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data663_rabe_266 [Errno 2] No such file or directory: '../experiments/experiment_000016/repetition_000002/data663_rabe_266/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000016/repetition_000000/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data228_elusage [Errno 2] No such file or directory: '../experiments/experiment_000016/repetition_000001/data228_elusage/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000017/repetition_000003/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000017/repetition_000002/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000017/repetition_000000/data678_visualizing_environmental/train_loss.npy'
# Error reading files for dataset:  data678_visualizing_environmental [Errno 2] No such file or directory: '../experiments/experiment_000017/repetition_000001/data678_visualizing_environmental/train_loss.npy'
# Min Val Loss:  0.018772798729287773
# Min Val Loss:  0.01857373138296632
# Min Val Loss:  0.01763609629105418
# Min Val Loss:  0.01741520022103032
# Min Val Loss:  0.01827570458778178
# Min Val Loss:  0.017938964580040243
# Min Val Loss:  0.016721072347327684
# Min Val Loss:  0.018319915026364007
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.019126          0.018678          0.017719
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.019583          0.018337          0.019342
#
#         repetition_000001 repetition_000006      mean
# housing          0.018081          0.019023  0.018736
# Min Val Loss:  0.16614148104162407
# Min Val Loss:  0.5712449167556447
# Min Val Loss:  0.02235572662860703
# Min Val Loss:  0.023885267784945964
# Min Val Loss:  0.12555094989946083
# Min Val Loss:  0.022421281966754646
# Min Val Loss:  0.024925884422590392
# Min Val Loss:  0.5750826039709684
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.022542          0.031192          0.022638
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.024317          0.021287          0.025407
#
#         repetition_000001 repetition_000006     mean
# housing          0.407277          0.021662  0.07204
# Min Val Loss:  0.010808019104613112
# Min Val Loss:  0.010933968451142416
# Min Val Loss:  0.009664589166211797
# Min Val Loss:  0.009843287727934372
# Min Val Loss:  0.0099980582972759
# Min Val Loss:  0.009935369514663754
# Min Val Loss:  0.00925373225369257
# Min Val Loss:  0.010838086792492057
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.010485          0.011097          0.010022
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.011308          0.010502          0.011544
#
#         repetition_000001 repetition_000006      mean
# housing          0.011652          0.011461  0.011009
# Min Val Loss:  0.15724249836057425
# Min Val Loss:  0.1569472593255341
# Min Val Loss:  0.14907409716397524
# Min Val Loss:  0.15180975385010242
# Min Val Loss:  0.14649289892986417
# Min Val Loss:  0.14461288787424564
# Min Val Loss:  0.16026344569399953
# Min Val Loss:  0.16247469140216708
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.158614          0.182187          0.139023
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.176854          0.154585          0.168185
#
#         repetition_000001 repetition_000006     mean
# housing          1.196834          0.159802  0.29201
# Min Val Loss:  0.16198504343628883
# Min Val Loss:  0.18193010054528713
# Min Val Loss:  0.1507944385521114
# Min Val Loss:  0.146008743904531
# Min Val Loss:  0.15552901849150658
# Min Val Loss:  0.14534523151814938
# Min Val Loss:  0.15781558910384774
# Min Val Loss:  0.18809521477669477
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.165745          0.191671          0.150277
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing           0.16658          0.161087          0.168908
#
#         repetition_000001 repetition_000006      mean
# housing          0.239473          0.193237  0.179622
# Min Val Loss:  0.22197115002200007
# Min Val Loss:  0.17839625151827931
# Min Val Loss:  0.16842455975711346
# Min Val Loss:  0.17565697943791747
# Min Val Loss:  0.18020542711019516
# Min Val Loss:  0.17545797768980265
# Min Val Loss:  0.18749308725818992
# Min Val Loss:  0.21740601072087884
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.203492          0.186631          0.165942
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.183821           0.17339          0.196642
#
#         repetition_000001 repetition_000006      mean
# housing          0.256991          0.212722  0.197454
# Min Val Loss:  0.1749125043861568
# Min Val Loss:  0.18886081408709288
# Min Val Loss:  0.21727450750768185
# Min Val Loss:  0.20569016225636005
# Min Val Loss:  0.16581392847001553
# Min Val Loss:  0.2264151144772768
# Min Val Loss:  0.20885706413537264
# Min Val Loss:  0.20164508884772658
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.176794           0.19946          0.215545
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.224795          0.174382          0.253535
#
#         repetition_000001 repetition_000006      mean
# housing            0.2165           0.19776  0.207346
# Min Val Loss:  0.15158334001898766
# Min Val Loss:  0.17138301581144333
# Min Val Loss:  0.15309089375659823
# Min Val Loss:  0.15628941729664803
# Min Val Loss:  0.1626583910547197
# Min Val Loss:  0.15354196541011333
# Min Val Loss:  0.1598527985624969
# Min Val Loss:  0.20789904799312353
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.163886          0.182922          0.153472
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing           0.18153          0.165861          0.180478
#
#         repetition_000001 repetition_000006          mean
# housing     157904.582312          0.216395  19738.228357
# Min Val Loss:  0.2917829919606447
# Min Val Loss:  0.2951631583273411
# Min Val Loss:  0.27662751683965325
# Min Val Loss:  0.27937596943229437
# Min Val Loss:  0.2530954238027334
# Min Val Loss:  0.2226273389533162
# Min Val Loss:  0.26308464631438255
# Min Val Loss:  0.28754925820976496
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.288072            0.3006          0.273835
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.309968          0.258082          0.247773
#
#         repetition_000001 repetition_000006      mean
# housing          0.291144           0.29783  0.283413
# Min Val Loss:  0.20394512871280313
# Min Val Loss:  0.19047165801748633
# Min Val Loss:  0.19989279191941023
# Min Val Loss:  0.20397994294762611
# Min Val Loss:  0.17806085012853146
# Min Val Loss:  0.19091141829267144
# Min Val Loss:  0.20309670455753803
# Min Val Loss:  0.2572962651029229
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.208771          0.198272          0.194398
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.230521          0.184829          0.202441
#
#         repetition_000001 repetition_000006      mean
# housing          0.232832          0.276273  0.216042
# Min Val Loss:  0.23252050951123238
# Min Val Loss:  0.25909057166427374
# Min Val Loss:  0.25229279324412346
# Min Val Loss:  0.22558425553143024
# Min Val Loss:  0.25756492279469967
# Min Val Loss:  0.26822141371667385
# Min Val Loss:  0.20228140149265528
# Min Val Loss:  0.2525797002017498
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.237938          0.264279          0.258044
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing           0.25162            0.2643          0.300735
#
#         repetition_000001 repetition_000006      mean
# housing          0.236423          0.276955  0.261287
# Min Val Loss:  0.2971743931993842
# Min Val Loss:  0.30330535862594843
# Min Val Loss:  0.28542192094027996
# Min Val Loss:  0.2862633401528001
# Min Val Loss:  0.29299259185791016
# Min Val Loss:  0.2547870818525553
# Min Val Loss:  0.26957286056131124
# Min Val Loss:  0.29970906488597393
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.306759          0.307192          0.281958
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing           0.31162          0.299771          0.281627
#
#         repetition_000001 repetition_000006      mean
# housing          0.298184          0.305888  0.299125
# Min Val Loss:  0.27806190215051174
# Min Val Loss:  0.2733668964356184
# Min Val Loss:  0.2231287555769086
# Min Val Loss:  0.21740693878382444
# Min Val Loss:  0.20184457208961248
# Min Val Loss:  0.26233262615278363
# Min Val Loss:  0.26012588385492563
# Min Val Loss:  0.2826878558844328
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.292106          0.278252          0.221373
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.252308           0.20099          0.285797
#
#         repetition_000001 repetition_000006      mean
# housing          0.287316          0.302069  0.265026
# Min Val Loss:  0.275286627933383
# Min Val Loss:  0.28681433387100697
# Min Val Loss:  0.21889902371913195
# Min Val Loss:  0.26853321120142937
# Min Val Loss:  0.19794967444613576
# Min Val Loss:  0.2753488402813673
# Min Val Loss:  0.20499189756810665
# Min Val Loss:  0.27563657239079475
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.282005          0.288685          0.215527
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.299245          0.203461          0.301262
#
#         repetition_000001 repetition_000006      mean
# housing          0.234384          0.296466  0.265129
# Min Val Loss:  0.29883098509162664
# Min Val Loss:  0.30931301042437553
# Min Val Loss:  0.295977340079844
# Min Val Loss:  0.2893805783241987
# Min Val Loss:  0.2970006661489606
# Min Val Loss:  0.2533605843782425
# Min Val Loss:  0.2735108295455575
# Min Val Loss:  0.3013320183381438
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.304907          0.314842          0.296605
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.317797          0.299948          0.280266
#
#         repetition_000001 repetition_000006     mean
# housing          0.301308          0.310409  0.30326
# Min Val Loss:  0.18065765174105763
# Min Val Loss:  0.17953509464859962
# Min Val Loss:  0.18682229705154896
# Min Val Loss:  0.15846176212653518
# Min Val Loss:  0.17038463708013296
# Min Val Loss:  0.1739046946167946
# Min Val Loss:  0.15126685332506895
# Min Val Loss:  0.1665551238693297
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.185086           0.18749          0.177457
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.182135          0.179988          0.189133
#
#         repetition_000001 repetition_000006      mean
# housing          0.183415          0.187143  0.183981
# Min Val Loss:  0.16221549035981297
# Min Val Loss:  0.1507741012610495
# Min Val Loss:  0.15218483842909336
# Min Val Loss:  0.14192131767049432
# Min Val Loss:  0.1626574769616127
# Min Val Loss:  0.14722363464534283
# Min Val Loss:  0.12970010098069906
# Min Val Loss:  0.14874087506905198
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.161191          0.163374          0.138303
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.162692          0.149254          0.173903
#
#         repetition_000001 repetition_000006      mean
# housing          0.174079          0.157893  0.160086
# Min Val Loss:  0.20059386221691966
# Min Val Loss:  0.19504455383867025
# Min Val Loss:  0.18627658020704985
# Min Val Loss:  0.1666767061688006
# Min Val Loss:  0.19322685152292252
# Min Val Loss:  0.17712331842631102
# Min Val Loss:  0.16924093896523118
# Min Val Loss:  0.17642074963077903
#          repetition_000003 repetition_000004 repetition_000005  \
# housing            0.17989          0.206327          0.181723
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.179062          0.167237          0.207846
#
#         repetition_000001 repetition_000006      mean
# housing          0.201069          0.190091  0.189156
# Min Val Loss:  0.2859636517241597
# Min Val Loss:  0.2341547692194581
# Min Val Loss:  0.2004333883523941
# Min Val Loss:  0.23188285436481237
# Min Val Loss:  0.20512686157599092
# Min Val Loss:  0.21539991442114115
# Min Val Loss:  0.20116607751697302
# Min Val Loss:  0.20440884307026863
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.297976          0.246489          0.198834
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.254254          0.208044          0.248409
#
#         repetition_000001 repetition_000006      mean
# housing          0.245996          0.228375  0.241047
# Min Val Loss:  0.28611691296100616
# Min Val Loss:  0.26350961439311504
# Min Val Loss:  0.1957697318866849
# Min Val Loss:  0.2462806273251772
# Min Val Loss:  0.19850929826498032
# Min Val Loss:  0.22343273647129536
# Min Val Loss:  0.1872364399023354
# Min Val Loss:  0.2234887620434165
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.292591          0.271639          0.198119
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.277814          0.202075          0.249898
#
#         repetition_000001 repetition_000006     mean
# housing          0.233596           0.23099  0.24459
# Min Val Loss:  0.29913357738405466
# Min Val Loss:  0.2887199707329273
# Min Val Loss:  0.22927091736346483
# Min Val Loss:  0.26127942837774754
# Min Val Loss:  0.24442618992179632
# Min Val Loss:  0.2784033380448818
# Min Val Loss:  0.26233142893761396
# Min Val Loss:  0.25087147764861584
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.309668           0.29156          0.224726
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.294379          0.250849          0.308411
#
#         repetition_000001 repetition_000006      mean
# housing          0.287639          0.267953  0.279398
# Min Val Loss:  0.3083388991653919
# Min Val Loss:  0.2671827292069793
# Min Val Loss:  0.21873564925044775
# Min Val Loss:  0.2796546509489417
# Min Val Loss:  0.2703622253611684
# Min Val Loss:  0.26874429918825626
# Min Val Loss:  0.24860202334821224
# Min Val Loss:  0.28188975248485804
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.313769           0.28598          0.219619
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.324304          0.266595          0.298308
#
#         repetition_000001 repetition_000006      mean
# housing          0.293724          0.314815  0.289639
# Min Val Loss:  0.27909776754677296
# Min Val Loss:  0.2750328276306391
# Min Val Loss:  0.21155641973018646
# Min Val Loss:  0.2675684541463852
# Min Val Loss:  0.2727938452735543
# Min Val Loss:  0.2680667117238045
# Min Val Loss:  0.2519783787429333
# Min Val Loss:  0.27618532069027424
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.275894          0.279315          0.213787
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.307331          0.265655          0.312365
#
#         repetition_000001 repetition_000006     mean
# housing            0.2732          0.313092  0.28008
# Min Val Loss:  0.2853942671790719
# Min Val Loss:  0.27183522284030914
# Min Val Loss:  0.2367231398820877
# Min Val Loss:  0.2753443503752351
# Min Val Loss:  0.27158805541694164
# Min Val Loss:  0.2670292342081666
# Min Val Loss:  0.2617633119225502
# Min Val Loss:  0.2807944896630943
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.272173          0.276695          0.220313
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.307255          0.270979          0.313739
#
#         repetition_000001 repetition_000006      mean
# housing           0.27324          0.327012  0.282676
# Min Val Loss:  0.9154961779713631
# Min Val Loss:  0.913677878677845
# Min Val Loss:  0.8873328380286694
# Min Val Loss:  0.8768149316310883
# Min Val Loss:  0.9349769428372383
# Min Val Loss:  0.9230177998542786
# Min Val Loss:  0.9504625834524632
# Min Val Loss:  0.9416336975991726
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.955462          0.934965          0.936577
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.976257          0.947624          0.940566
#
#         repetition_000001 repetition_000006      mean
# housing          0.923091          0.956838  0.946423
# Min Val Loss:  0.9128596372902393
# Min Val Loss:  0.9418578408658504
# Min Val Loss:  0.8926944583654404
# Min Val Loss:  0.8810363039374352
# Min Val Loss:  0.9370532035827637
# Min Val Loss:  0.9236013032495975
# Min Val Loss:  0.9487439654767513
# Min Val Loss:  0.9397245533764362
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.969247          0.967493          0.923287
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.980157          0.945223          0.948262
#
#         repetition_000001 repetition_000006      mean
# housing          0.922846          0.970066  0.953323
# Min Val Loss:  0.9151471741497517
# Min Val Loss:  0.9311618097126484
# Min Val Loss:  0.8970800191164017
# Min Val Loss:  0.8781215697526932
# Min Val Loss:  0.936581190675497
# Min Val Loss:  0.9237584695219994
# Min Val Loss:  0.9462928138673306
# Min Val Loss:  0.9399014450609684
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.965434          0.948899          0.931982
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.972829          0.950237          0.947044
#
#         repetition_000001 repetition_000006      mean
# housing          0.928201          0.978941  0.952946
# Min Val Loss:  0.23751939926296473
# Min Val Loss:  0.21940629929304123
# Min Val Loss:  0.2583030853420496
# Min Val Loss:  0.22307702619582415
# Min Val Loss:  0.1934497239999473
# Min Val Loss:  0.20128596015274525
# Min Val Loss:  0.9459636192768812
# Min Val Loss:  0.20315262489020824
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.244842          0.224669          0.266019
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.240295          0.192013          0.212549
#
#         repetition_000001 repetition_000006      mean
# housing          0.931584          0.212164  0.315517
# Min Val Loss:  0.250369418412447
# Min Val Loss:  0.20848300773650408
# Min Val Loss:  0.23869134299457073
# Min Val Loss:  0.1878201151266694
# Min Val Loss:  0.2097369348630309
# Min Val Loss:  0.20045596174895763
# Min Val Loss:  0.18823137832805514
# Min Val Loss:  0.21607730723917484
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.251507          0.210406          0.243098
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.208149             0.205          0.215528
#
#         repetition_000001 repetition_000006      mean
# housing          0.241149          0.229303  0.225517
# Min Val Loss:  0.35108037665486336
# Min Val Loss:  0.2808845331892371
# Min Val Loss:  0.25841307267546654
# Min Val Loss:  0.2378987930715084
# Min Val Loss:  0.23637261427938938
# Min Val Loss:  0.21432857774198055
# Min Val Loss:  0.24536406062543392
# Min Val Loss:  0.2308095283806324
#          repetition_000003 repetition_000004 repetition_000005  \
# housing            0.31627          0.282084          0.261891
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.250331          0.219971          0.226181
#
#         repetition_000001 repetition_000006      mean
# housing            0.2972          0.243813  0.262218
# Min Val Loss:  0.15915670013055205
# Min Val Loss:  0.16526164952665567
# Min Val Loss:  0.1940843528136611
# Min Val Loss:  0.18956125527620316
# Min Val Loss:  0.16918659629300237
# Min Val Loss:  0.15306577179580927
# Min Val Loss:  0.13216293696314096
# Min Val Loss:  0.1856993124820292
#          repetition_000003 repetition_000004 repetition_000005  \
# housing            0.16246          0.184053          0.194018
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.214219          0.172154          0.169375
#
#         repetition_000001 repetition_000006      mean
# housing           0.17149           0.18835  0.182015
# Min Val Loss:  0.17317464901134372
# Min Val Loss:  0.15547031071037054
# Min Val Loss:  0.19256247952580452
# Min Val Loss:  0.1606867639347911
# Min Val Loss:  0.15712046949192882
# Min Val Loss:  0.15650999546051025
# Min Val Loss:  0.14953742176294327
# Min Val Loss:  0.17185997171327472
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.157432          0.191484          0.190481
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.177117          0.166535          0.196358
#
#         repetition_000001 repetition_000006     mean
# housing          0.178014          0.172582  0.17875
# Min Val Loss:  0.195484587457031
# Min Val Loss:  0.19133644364774227
# Min Val Loss:  0.19787374511361122
# Min Val Loss:  0.17586009250953794
# Min Val Loss:  0.1750875599682331
# Min Val Loss:  0.16877767723053694
# Min Val Loss:  0.1457267045043409
# Min Val Loss:  0.17302680714055896
#          repetition_000003 repetition_000004 repetition_000005  \
# housing            0.19653          0.201967          0.198043
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.196997          0.177318          0.193613
#
#         repetition_000001 repetition_000006      mean
# housing          0.178975          0.179192  0.190329
# Min Val Loss:  0.17241007834672928
# Min Val Loss:  0.19536777073517442
# Min Val Loss:  0.23129772953689098
# Min Val Loss:  0.18079532030969858
# Min Val Loss:  0.23261760361492634
# Min Val Loss:  0.20076613686978817
# Min Val Loss:  0.17970903404057026
# Min Val Loss:  0.17015435174107552
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.178387          0.175947          0.221563
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.208313          0.249176          0.203174
#
#         repetition_000001 repetition_000006      mean
# housing          0.209422          0.174249  0.202529
# Min Val Loss:  0.18000906286761165
# Min Val Loss:  0.19243314815685153
# Min Val Loss:  0.23984869197010994
# Min Val Loss:  0.1816046042367816
# Min Val Loss:  0.22975216526538134
# Min Val Loss:  0.1946793356910348
# Min Val Loss:  0.18648373801261187
# Min Val Loss:  0.1620629308745265
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.164225           0.20211          0.220049
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.213534          0.239389          0.210689
#
#         repetition_000001 repetition_000006     mean
# housing          0.204456          0.183871  0.20479
# Min Val Loss:  0.17073150631040335
# Min Val Loss:  0.2088333936408162
# Min Val Loss:  0.23857696074992418
# Min Val Loss:  0.18411635514348745
# Min Val Loss:  0.24272904451936483
# Min Val Loss:  0.19248149450868368
# Min Val Loss:  0.18722295062616467
# Min Val Loss:  0.17190331919118762
#          repetition_000003 repetition_000004 repetition_000005  \
# housing           0.170263          0.204186           0.21983
#
#         repetition_000002 repetition_000007 repetition_000000  \
# housing          0.210779           0.25724          0.211119
#
#         repetition_000001 repetition_000006      mean
# housing          0.186774          0.173735  0.204241
#                                                svr              pls  \
# data1027_ESL                              0.323865         0.304508
# data1029_LEV                              0.345005         0.350703
# data1030_ERA                              2.569014          2.52284
# data1096_FacultySalaries                 19.121715         8.053305
# data192_vineyard                         11.556423         8.028631
# data210_cloud                             0.326421         0.213084
# data228_elusage                         552.948593       154.669425
# data485_analcatdata_vehicle           86945.664481     44820.749059
# data519_vinnie                            4.118501         2.474889
# data523_analcatdata_neavote               3.571094         1.600707
# data529_pollen                            2.285323         2.002318
# data556_analcatdata_apnea2         11818856.233981  10823920.074627
# data579_fri_c0_250_5                      0.138249         0.284469
# data663_rabe_266                       1623.775858        52.823275
# data678_visualizing_environmental         9.779421         7.800956
# data687_sleuth_ex1605                   214.838265       107.244542
# data690_visualizing_galaxy             6443.644057       866.126213
# data712_chscase_geyser1                 152.336098        36.795538
# databanana                                0.078596         0.246278
#
#                                         gradboost        mlp_0.01  \
# data1027_ESL                             0.336749        0.329864
# data1029_LEV                             0.361915        0.707251
# data1030_ERA                             2.666996         5.20141
# data1096_FacultySalaries                 6.576213        3.972139
# data192_vineyard                        13.355531        26.92001
# data210_cloud                             0.24788        0.227685
# data228_elusage                        223.418803      241.916058
# data485_analcatdata_vehicle          32767.363626    39457.353516
# data519_vinnie                            2.79157        2.514356
# data523_analcatdata_neavote              2.914713        5.317144
# data529_pollen                           2.358644       13.869105
# data556_analcatdata_apnea2         1387467.609311  3679185.984375
# data579_fri_c0_250_5                     0.199945        0.099396
# data663_rabe_266                        11.282661       53.680381
# data678_visualizing_environmental       10.476897       13.796402
# data687_sleuth_ex1605                   93.945796      114.120095
# data690_visualizing_galaxy             266.910413      620.450478
# data712_chscase_geyser1                 49.948522      730.123466
# databanana                               0.078581        0.593094
#
#                                       mlp_0.001     mlp_0.0001 rbf_full_0.01  \
# data1027_ESL                           0.308289       0.344512           NaN
# data1029_LEV                           0.708282       0.692499           NaN
# data1030_ERA                           5.151847       5.064639           NaN
# data1096_FacultySalaries               3.942295        6.66034           NaN
# data192_vineyard                       8.192711       9.557277     10.504754
# data210_cloud                          0.251061       0.233084      1.071425
# data228_elusage                       932.29604     1676.82869           NaN
# data485_analcatdata_vehicle        37199.203125  116710.407227           NaN
# data519_vinnie                         8.223022      12.120766           NaN
# data523_analcatdata_neavote            9.398788       9.121361           NaN
# data529_pollen                        13.309261      13.688972           NaN
# data556_analcatdata_apnea2          10015232.25   11045982.375           NaN
# data579_fri_c0_250_5                   0.084238       0.105005           NaN
# data663_rabe_266                      82.122571      110.65666           NaN
# data678_visualizing_environmental     26.905381      30.506876           NaN
# data687_sleuth_ex1605                113.714704     146.875151           NaN
# data690_visualizing_galaxy          2014.341446  253880.382812           NaN
# data712_chscase_geyser1             1239.642672     211.927563           NaN
# databanana                              0.62029       0.592695           NaN
#
#                                    rbf_full_0.001 rbf_full_0.0001  \
# data1027_ESL                                  NaN             NaN
# data1029_LEV                                  NaN             NaN
# data1030_ERA                                  NaN             NaN
# data1096_FacultySalaries                      NaN             NaN
# data192_vineyard                        80.457599       87.765315
# data210_cloud                            0.720932        0.416617
# data228_elusage                    6758100.390991    45776.541023
# data485_analcatdata_vehicle         122954.541016    72777.393555
# data519_vinnie                           2.636747        2.750249
# data523_analcatdata_neavote             10.395859       26.749773
# data529_pollen                                NaN      113.266441
# data556_analcatdata_apnea2                    NaN       9491218.0
# data579_fri_c0_250_5                          NaN        0.124284
# data663_rabe_266                              NaN     4637.176056
# data678_visualizing_environmental             NaN             NaN
# data687_sleuth_ex1605                         NaN             NaN
# data690_visualizing_galaxy                    NaN             NaN
# data712_chscase_geyser1                       NaN             NaN
# databanana                                    NaN             NaN
#
#                                   rbf_diag_0.01  ...  ffn_10_0.0001  \
# data1027_ESL                                NaN  ...       1.738068
# data1029_LEV                                NaN  ...       0.812212
# data1030_ERA                                NaN  ...       5.392627
# data1096_FacultySalaries                    NaN  ...      37.830108
# data192_vineyard                       7.985293  ...      26.441723
# data210_cloud                          0.285877  ...       1.085914
# data228_elusage                             NaN  ...     795.349602
# data485_analcatdata_vehicle                 NaN  ...   107513.53418
# data519_vinnie                              NaN  ...       8.017724
# data523_analcatdata_neavote                 NaN  ...       2.391112
# data529_pollen                              NaN  ...       82.62418
# data556_analcatdata_apnea2                  NaN  ...   10955076.125
# data579_fri_c0_250_5                        NaN  ...       1.046296
# data663_rabe_266                            NaN  ...     2893.92572
# data678_visualizing_environmental           NaN  ...      11.544014
# data687_sleuth_ex1605                       NaN  ...    1222.712173
# data690_visualizing_galaxy                  NaN  ...  123653.944336
# data712_chscase_geyser1                     NaN  ...     183.214977
# databanana                                  NaN  ...       2.255368
#
#                                   uffn_0.1_0.01  uffn_0.1_0.001  \
# data1027_ESL                           0.367704        0.357255
# data1029_LEV                           0.726942         0.69651
# data1030_ERA                           5.194787        5.229344
# data1096_FacultySalaries              22.983537        21.96038
# data192_vineyard                      13.149638        9.991056
# data210_cloud                          0.322259         0.34646
# data228_elusage                      344.554035      339.558239
# data485_analcatdata_vehicle        52142.318848    46496.493652
# data519_vinnie                         2.851499        2.862674
# data523_analcatdata_neavote            1.688295        1.752749
# data529_pollen                        17.757675       17.832621
# data556_analcatdata_apnea2          4026821.375  4316872.585938
# data579_fri_c0_250_5                   0.128347        0.101929
# data663_rabe_266                      17.302278       20.647344
# data678_visualizing_environmental     11.375067       11.159628
# data687_sleuth_ex1605                201.761505      205.605015
# data690_visualizing_galaxy          3962.923874     8361.093384
# data712_chscase_geyser1               41.101557       40.622129
# databanana                             0.586565        0.593376
#
#                                   uffn_0.1_0.0001   uffn_1_0.01  \
# data1027_ESL                             0.334018      0.330218
# data1029_LEV                             0.693348      0.719256
# data1030_ERA                             5.114284      5.286727
# data1096_FacultySalaries                36.588775     33.591023
# data192_vineyard                        20.491158     24.300825
# data210_cloud                            0.323559      0.557538
# data228_elusage                        574.149658     512.60984
# data485_analcatdata_vehicle         108635.061523  35290.619141
# data519_vinnie                          13.678187      3.191839
# data523_analcatdata_neavote              6.483002       1.14241
# data529_pollen                           16.56501     60.948512
# data556_analcatdata_apnea2             10854880.0    1683017.75
# data579_fri_c0_250_5                     0.129763      0.213887
# data663_rabe_266                      2553.935242     21.345558
# data678_visualizing_environmental       12.123644     13.250025
# data687_sleuth_ex1605                 1043.894627    336.029911
# data690_visualizing_galaxy          139313.431641  19700.677002
# data712_chscase_geyser1                160.158056     46.928443
# databanana                               0.599237      0.656293
#
#                                     uffn_1_0.001  uffn_1_0.0001  \
# data1027_ESL                            0.323877       0.343482
# data1029_LEV                             0.68628        0.71084
# data1030_ERA                            5.374817        5.32548
# data1096_FacultySalaries               31.345253      40.149459
# data192_vineyard                       17.118182      30.992633
# data210_cloud                           0.482953       0.503424
# data228_elusage                       488.600227     670.814957
# data485_analcatdata_vehicle          41466.80127  106399.946289
# data519_vinnie                          3.572262       5.153314
# data523_analcatdata_neavote              1.21055       2.948215
# data529_pollen                         45.107928        46.2926
# data556_analcatdata_apnea2         1500666.15625   10098307.625
# data579_fri_c0_250_5                    0.201517        0.19421
# data663_rabe_266                       13.061029    2657.485291
# data678_visualizing_environmental      13.269208      13.093281
# data687_sleuth_ex1605                 347.609818     992.227768
# data690_visualizing_galaxy          21368.660645  120365.611328
# data712_chscase_geyser1                49.832385     133.605116
# databanana                               0.63428       0.629381
#
#                                      uffn_10_0.01   uffn_10_0.001  \
# data1027_ESL                             0.321966        0.302703
# data1029_LEV                             0.733261        0.692628
# data1030_ERA                             5.278253        5.370487
# data1096_FacultySalaries                29.887124       30.218133
# data192_vineyard                         32.91191       26.534364
# data210_cloud                            1.037352        1.023348
# data228_elusage                        434.158344      429.243118
# data485_analcatdata_vehicle          30643.455566    39493.773926
# data519_vinnie                           3.067147        3.243468
# data523_analcatdata_neavote              1.172666        1.160513
# data529_pollen                          63.934997        81.20789
# data556_analcatdata_apnea2         1733214.671875  1589321.578125
# data579_fri_c0_250_5                     0.968058        0.955024
# data663_rabe_266                         9.771542       23.261524
# data678_visualizing_environmental       15.144679       15.217313
# data687_sleuth_ex1605                  216.169275      210.982031
# data690_visualizing_galaxy           17902.267334    18277.664307
# data712_chscase_geyser1                 56.283418       51.918796
# databanana                               1.340141        1.408018
#
#                                   uffn_10_0.0001
# data1027_ESL                            0.337092
# data1029_LEV                            0.699434
# data1030_ERA                            5.310369
# data1096_FacultySalaries               37.962555
# data192_vineyard                       30.158894
# data210_cloud                           1.031165
# data228_elusage                       635.704506
# data485_analcatdata_vehicle        107846.702148
# data519_vinnie                          5.334881
# data523_analcatdata_neavote             2.126074
# data529_pollen                         82.681778
# data556_analcatdata_apnea2          10027595.625
# data579_fri_c0_250_5                     0.95538
# data663_rabe_266                     2517.914795
# data678_visualizing_environmental      12.694172
# data687_sleuth_ex1605                 944.163227
# data690_visualizing_galaxy         144255.269531
# data712_chscase_geyser1               178.179256
# databanana                              1.434445
#
# [19 rows x 36 columns]

# %%
condensed_experiments_df = pd.DataFrame()
## iterate over the condensed method names and pick the min test loss for the corresponding methods 
for condensed_method in condensed_method_names:
    condensed_experiments_df[condensed_method] = experiments_df[[method for method in method_names if method.startswith(condensed_method)]].min(axis=1)

## set all None to nan
condensed_experiments_df = condensed_experiments_df.replace({None: np.nan})

condensed_experiments_df
# Out:
#                                             svr           pls     gradboost  \
# data1027_ESL                       3.238651e-01  3.045083e-01  3.367491e-01
# data1029_LEV                       3.450054e-01  3.507035e-01  3.619152e-01
# data1030_ERA                       2.569014e+00  2.522840e+00  2.666996e+00
# data1096_FacultySalaries           1.912172e+01  8.053305e+00  6.576213e+00
# data192_vineyard                   1.155642e+01  8.028631e+00  1.335553e+01
# data210_cloud                      3.264215e-01  2.130838e-01  2.478801e-01
# data228_elusage                    5.529486e+02  1.546694e+02  2.234188e+02
# data485_analcatdata_vehicle        8.694566e+04  4.482075e+04  3.276736e+04
# data519_vinnie                     4.118501e+00  2.474889e+00  2.791570e+00
# data523_analcatdata_neavote        3.571094e+00  1.600707e+00  2.914713e+00
# data529_pollen                     2.285323e+00  2.002318e+00  2.358644e+00
# data556_analcatdata_apnea2         1.181886e+07  1.082392e+07  1.387468e+06
# data579_fri_c0_250_5               1.382487e-01  2.844692e-01  1.999446e-01
# data663_rabe_266                   1.623776e+03  5.282327e+01  1.128266e+01
# data678_visualizing_environmental  9.779421e+00  7.800956e+00  1.047690e+01
# data687_sleuth_ex1605              2.148383e+02  1.072445e+02  9.394580e+01
# data690_visualizing_galaxy         6.443644e+03  8.661262e+02  2.669104e+02
# data712_chscase_geyser1            1.523361e+02  3.679554e+01  4.994852e+01
# databanana                         7.859584e-02  2.462780e-01  7.858065e-02
#
#                                             mlp      rbf_full      rbf_diag  \
# data1027_ESL                       3.082891e-01           NaN           NaN
# data1029_LEV                       6.924995e-01           NaN           NaN
# data1030_ERA                       5.064639e+00           NaN           NaN
# data1096_FacultySalaries           3.942295e+00           NaN           NaN
# data192_vineyard                   8.192711e+00  1.050475e+01  7.985293e+00
# data210_cloud                      2.276848e-01  4.166170e-01  2.507781e-01
# data228_elusage                    2.419161e+02  4.577654e+04  5.224687e+04
# data485_analcatdata_vehicle        3.719920e+04  7.277739e+04  5.015693e+04
# data519_vinnie                     2.514356e+00  2.636747e+00  2.576199e+00
# data523_analcatdata_neavote        5.317144e+00  1.039586e+01  1.054052e+01
# data529_pollen                     1.330926e+01  1.132664e+02  1.439003e+01
# data556_analcatdata_apnea2         3.679186e+06  9.491218e+06  5.024052e+06
# data579_fri_c0_250_5               8.423757e-02  1.242842e-01  1.208480e-01
# data663_rabe_266                   5.368038e+01  4.637176e+03  9.071591e+02
# data678_visualizing_environmental  1.379640e+01           NaN           NaN
# data687_sleuth_ex1605              1.137147e+02           NaN           NaN
# data690_visualizing_galaxy         6.204505e+02           NaN           NaN
# data712_chscase_geyser1            2.119276e+02           NaN           NaN
# databanana                         5.926945e-01           NaN           NaN
#
#                                        rbf_scal      rbf_univ           ffn  \
# data1027_ESL                                NaN  3.921763e-01  3.270956e-01
# data1029_LEV                                NaN  7.150353e-01  7.383197e-01
# data1030_ERA                                NaN  5.163117e+00  5.307643e+00
# data1096_FacultySalaries                    NaN  7.684430e+00  2.782543e+01
# data192_vineyard                   7.639175e+00  1.345018e+01  1.342368e+01
# data210_cloud                      2.825808e-01  4.224689e-01  3.670831e-01
# data228_elusage                    2.213522e+06  2.591982e+02  4.922708e+02
# data485_analcatdata_vehicle        3.746382e+04  4.289199e+04  4.090596e+04
# data519_vinnie                     2.683433e+00  2.600116e+00  2.984501e+00
# data523_analcatdata_neavote        1.053600e+01  1.324801e+00  1.747266e+00
# data529_pollen                     3.181323e+01  1.544593e+01  6.554184e+01
# data556_analcatdata_apnea2         1.143684e+07  1.723223e+06  1.088094e+07
# data579_fri_c0_250_5               1.384794e-01  2.651270e-01  1.592660e-01
# data663_rabe_266                   2.445140e+03  2.376046e+02  2.800807e+03
# data678_visualizing_environmental           NaN  4.402965e+01  1.123401e+01
# data687_sleuth_ex1605                       NaN  1.621134e+03  2.286187e+02
# data690_visualizing_galaxy                  NaN  1.079199e+06  1.683646e+04
# data712_chscase_geyser1                     NaN  1.282536e+02  4.347514e+01
# databanana                                  NaN  6.208581e-01  5.842338e-01
#
#                                            uffn
# data1027_ESL                       3.027034e-01
# data1029_LEV                       6.862798e-01
# data1030_ERA                       5.114284e+00
# data1096_FacultySalaries           2.196038e+01
# data192_vineyard                   9.991056e+00
# data210_cloud                      3.222592e-01
# data228_elusage                    3.395582e+02
# data485_analcatdata_vehicle        3.064346e+04
# data519_vinnie                     2.851499e+00
# data523_analcatdata_neavote        1.142410e+00
# data529_pollen                     1.656501e+01
# data556_analcatdata_apnea2         1.500666e+06
# data579_fri_c0_250_5               1.019292e-01
# data663_rabe_266                   9.771542e+00
# data678_visualizing_environmental  1.115963e+01
# data687_sleuth_ex1605              2.017615e+02
# data690_visualizing_galaxy         3.962924e+03
# data712_chscase_geyser1            4.062213e+01
# databanana                         5.865652e-01

# %%
## visualize the results using matplotlib using a log scale and multiple bars per dataset 

import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

bar_width = 0.05
x = np.arange(len(condensed_experiments_df.index))

for i, method in enumerate(condensed_experiments_df.columns):
    plt.bar(x + i*bar_width, condensed_experiments_df[method], width=bar_width, label=method)

plt.xticks(x + (len(condensed_experiments_df.columns)/2)*bar_width, condensed_experiments_df.index, rotation=90)

plt.yscale("log")
plt.legend(condensed_experiments_df.columns)
plt.show()

# %%
### normalize the results by the mlp result for each dataset

normalized_experiments_df = condensed_experiments_df.copy()

for dataset in normalized_experiments_df.index:
    mlp_result = normalized_experiments_df.loc[dataset, "mlp"]
    normalized_experiments_df.loc[dataset] = normalized_experiments_df.loc[dataset] / mlp_result

# %%
### calculate an average across all datasets for each method and visualize the results

average_across_datasets = normalized_experiments_df.mean(axis=0)

print(average_across_datasets)

plt.figure(figsize=(20,10))
plt.bar(average_across_datasets.index, average_across_datasets)
plt.xticks(rotation=90)

plt.yscale("log")

plt.show()
# Out:
# svr            3.462757
# pls            1.054082
# gradboost      0.816497
# mlp            1.000000
# rbf_full      29.624755
# rbf_diag      24.318308
# rbf_scal     920.888222
# rbf_univ      93.682145
# ffn            5.854416
# uffn           1.471610
# dtype: float64
